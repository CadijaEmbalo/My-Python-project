# %% [markdown]
# <a href="https://colab.research.google.com/github/CadijaEmbalo/My-Python-project/blob/main/Pandas_Day_1_cadija_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Requirement already satisfied means library already installed.

# %%
#create report of student with their mark less than 70 at class seven

# %%
# import pandas library
import pandas as pd

# %%
# check version
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_csv("student.csv")
# df represent dataframe.
# create df variable and assing it to dataset

# %%
df = pd.read_excel("student.xlsx")

# %%
df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
# first 5 rows
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
# first 10 rows
df.head(10)
# Out:
#    id         name  class  mark  gender
# 0   1     John Deo   Four    75  female
# 1   2     Max Ruin  Three    85    male
# 2   3       Arnold  Three    55    male
# 3   4   Krish Star   Four    60  female
# 4   5    John Mike   Four    60  female
# 5   6    Alex John   Four    55    male
# 6   7  My John Rob  Fifth    78    male
# 7   8       Asruid   Five    85    male
# 8   9      Tes Qry    Six    78     NaN
# 9  10     Big John   Four    55  female

# %%
# last 5 rows
df.tail()
# Out:
#     id         name  class  mark  gender
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
# last 10 rows
df.tail(10)
# Out:
#     id         name  class  mark  gender
# 25  26       Crelea  Seven    79    male
# 26  27          NaN  Three    81     NaN
# 27  28    Rojj Base  Seven    86  female
# 28  29  Tess Played  Seven    55    male
# 29  30    Reppy Red    Six    79  female
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
# head and tail method will return 5 rows by default

# %%
df.tail(1)
# Out:
#     id        name class  mark  gender
# 34  35  Rows Noump   Six    88  female

# %%
df.head(1)
# Out:
#    id      name class  mark  gender
# 0   1  John Deo  Four    75  female

# %%
# random data sample
df.sample()
# Out:
#     id    name class  mark  gender
# 19  20  Jackly  Nine    65  female

# %%
# 5 random samples
df.sample(5)
# Out:
#     id       name  class  mark  gender
# 15  16      Gimmy   Four    88    male
# 21  22     Reggid  Seven    55  female
# 19  20     Jackly   Nine    65  female
# 4    5  John Mike   Four    60  female
# 18  19      Tinny   Nine    18    male

# %%
# number of rows and columns
df.shape
# it doesnt have (). its an attribute
#(rows, columns)
# Out:
# (35, 5)

# %%
# dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    34 non-null     object
#  2   class   34 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  33 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %% [markdown]
# - look at the number of entries and compare it to Non-null count.
# - if they are different, that column has a missing value
# - name column has 34. 1 name is missing
# - class column has 1 missing data
# - gender column has 33. 2 info missing

# %% [markdown]
# - object data type is string

# %%
# name of the columns
df.columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
# statistical summary for numeric columns only
df.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %% [markdown]
# - std = standart deviation
# - 25%: 25% of the marks of the student are equal to or less than 62.5
# - 50% median. 50% of the marks of the student are equal to or less than 79
# - if std is close or greater than mean, there are outliers in your data

# %%
# number of rows
len(df)
# Out:
# 35

# %%
# rows * columns
df.size
# 35 * 5 = 175
# Out:
# 175

# %%
# datatypes of the columns
df.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %%
# Counts missing values per column.
df.isnull().sum()
# Out:
# id        0
# name      1
# class     1
# mark      0
# gender    2
# dtype: int64

# %%
# datatypes of the columns
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_236/2257627834.py in <cell line: 0>()
#       1 # datatypes of the columns
# ----> 2 df.dtypes
#       3
#
# NameError: name 'df' is not defined

# %%
# import pandas library
import pandas as pd

# %%
# check version
pd.__version__
# Out:
# '2.2.2'

# %%
df= pd.read_excel("student.xlsx")

# %%
# first 5 rows
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
# name of the columns
df.columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
# datatypes of the columns
df.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %%
# Counts missing values per column.
df.isnull().sum()
# Out:
# id        0
# name      1
# class     1
# mark      0
# gender    2
# dtype: int64

# %%
# Counts duplicate rows.

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["name"]
#slicing method
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26            NaN
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %%
df.gender.tail()
# Out:
# 30      male
# 31    female
# 32    female
# 33      male
# 34    female
# Name: gender, dtype: object

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.loc[0,4, "name","id","gender"]]
# Out:
#   File "/tmp/ipykernel_1097/232435727.py", line 1
#     df.loc[0,4, "name","id","gender"]]
#                                      ^
# SyntaxError: unmatched ']'

# %%
df.loc[0:4 , ["id", "name", "gender"]]
# these are list of the column names ["id", "name", "gender"]
# Out:
#    id        name  gender
# 0   1    John Deo  female
# 1   2    Max Ruin    male
# 2   3      Arnold    male
# 3   4  Krish Star  female
# 4   5   John Mike  female

# %%
df.iloc[0,1]
# Out:
# 'John Deo'

# %%
df.loc[11:16,["name", "mark"]]
# Out:
#         name  mark
# 11     Recky    94
# 12       Kty    88
# 13      Bigy    88
# 14  Tade Row    88
# 15     Gimmy    88
# 16     Tumyu    54

# %%
#create report of student with their mark less than 70 at class seven

# %%
df[ (df["mark"]<=70) & (df["class"]=="Seven")]
# Out:
#     id         name  class  mark  gender
# 21  22       Reggid  Seven    55  female
# 28  29  Tess Played  Seven    55    male
# 33  34     Gain Toe  Seven    69    male

# %%
#Average mark across all students
df["mark"]
# Out:
# 0     75
# 1     85
# 2     55
# 3     60
# 4     60
# 5     55
# 6     78
# 7     85
# 8     78
# 9     55
# 10    89
# 11    94
# 12    88
# 13    88
# 14    88
# 15    88
# 16    54
# 17    75
# 18    18
# 19    65
# 20    69
# 21    55
# 22    79
# 23    78
# 24    88
# 25    79
# 26    81
# 27    86
# 28    55
# 29    79
# 30    88
# 31    90
# 32    96
# 33    69
# 34    88
# Name: mark, dtype: int64

# %%
#average mark across female students
df["gender"] == "Female"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# Name: gender, dtype: bool

# %%
#Average mark across male

# %%
#average mark across female students
df["gender"] == "Male"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# Name: gender, dtype: bool

# %%
# Max and min mark
df.mark.max()
# Out:
# 96

# %%
#Max mark for male and max mark for female students

# %%
#Average mark for class 'Five'
df[df["class"]=="Five"]
# Out:
#     id    name class  mark gender
# 7    8  Asruid  Five    85   male
# 17  18   Honny  Five    75   male

# %%
#Average mark for class 'Six' and male students only
df[df["class"]=="six", "male"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# ...

# %%
df.loc[(df["gender"]=="male") & (df["mark"]>70)].sort_values(by="class")
# Out:
#     id         name  class  mark gender
# 22  23        Herod  Eight    79   male
# 6    7  My John Rob  Fifth    78   male
# 7    8       Asruid   Five    85   male
# 17  18        Honny   Five    75   male
# 15  16        Gimmy   Four    88   male
# 30  31  Marry Toeey   Four    88   male
# 23  24    Tiddy Now  Seven    78   male
# 24  25     Giff Tow  Seven    88   male
# 25  26       Crelea  Seven    79   male
# 1    2     Max Ruin  Three    85   male
# 14  15     Tade Row    NaN    88   male

# %%
df.sort_values(by="mark").head()
df.sort_values(by="name").head()

# %%
df.loc[(df["gender"]=="male") & (df["mark"]>70)].sort_values(by="class")
# Out:
#     id         name  class  mark gender
# 22  23        Herod  Eight    79   male
# 6    7  My John Rob  Fifth    78   male
# 7    8       Asruid   Five    85   male
# 17  18        Honny   Five    75   male
# 15  16        Gimmy   Four    88   male
# 30  31  Marry Toeey   Four    88   male
# 23  24    Tiddy Now  Seven    78   male
# 24  25     Giff Tow  Seven    88   male
# 25  26       Crelea  Seven    79   male
# 1    2     Max Ruin  Three    85   male
# 14  15     Tade Row    NaN    88   male

# %%
# female students who are above the classroom average. Sort the results in descending order.

# %%
df.loc[(df["gender"]=="female) & (df["mark"]>70)].sort_values(by="results")
# Out:
#   File "/tmp/ipykernel_1097/4021606071.py", line 1
#     df.loc[(df["gender"]=="female) & (df["mark"]>70)].sort_values(by="results")
#                                                                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df.loc[(df["gender"] =="female") & (df["mark"]>df.mark.mean())].sort_values( by="mark", ascending=False)
# Out:
#     id        name  class  mark  gender
# 32  33   Kenn Rein    Six    96  female
# 11  12       Recky    Six    94  female
# 31  32   Binn Rott  Seven    90  female
# 10  11      Ronald    Six    89  female
# 34  35  Rows Noump    Six    88  female
# 12  13         Kty  Seven    88  female
# 13  14        Bigy  Seven    88  female
# 27  28   Rojj Base  Seven    86  female
# 29  30   Reppy Red    Six    79  female
# 0    1    John Deo   Four    75  female

# %%
df["name"].value_counts()
# Out:
# name
# John Deo       1
# Max Ruin       1
# Arnold         1
# Krish Star     1
# John Mike      1
# Alex John      1
# My John Rob    1
# Asruid         1
# Tes Qry        1
# Big John       1
# Ronald         1
# Recky          1
# Kty            1
# Bigy           1
# Tade Row       1
# Gimmy          1
# Tumyu          1
# Honny          1
# Tinny          1
# Jackly         1
# Babby John     1
# Reggid         1
# Herod          1
# Tiddy Now      1
# Giff Tow       1
# Crelea         1
# Rojj Base      1
# Tess Played    1
# Reppy Red      1
# Marry Toeey    1
# Binn Rott      1
# Kenn Rein      1
# Gain Toe       1
# Rows Noump     1
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# male      17
# female    16
# Name: count, dtype: int64

# %%
df['mark'].value_counts()
# Out:
# mark
# 88    7
# 55    5
# 78    3
# 79    3
# 75    2
# 60    2
# 85    2
# 69    2
# 89    1
# 54    1
# 94    1
# 65    1
# 18    1
# 81    1
# 86    1
# 90    1
# 96    1
# Name: count, dtype: int64

# %%
df['class'].value_counts()
# Out:
# class
# Seven    10
# Four      8
# Six       7
# Three     3
# Nine      2
# Five      2
# Fifth     1
# Eight     1
# Name: count, dtype: int64

# %%
df['name'].value_counts()
# Out:
# name
# John Deo       1
# Max Ruin       1
# Arnold         1
# Krish Star     1
# John Mike      1
# Alex John      1
# My John Rob    1
# Asruid         1
# Tes Qry        1
# Big John       1
# Ronald         1
# Recky          1
# Kty            1
# Bigy           1
# Tade Row       1
# Gimmy          1
# Tumyu          1
# Honny          1
# Tinny          1
# Jackly         1
# Babby John     1
# Reggid         1
# Herod          1
# Tiddy Now      1
# Giff Tow       1
# Crelea         1
# Rojj Base      1
# Tess Played    1
# Reppy Red      1
# Marry Toeey    1
# Binn Rott      1
# Kenn Rein      1
# Gain Toe       1
# Rows Noump     1
# Name: count, dtype: int64

# %%
df['mark'].value_counts()
# Out:
# mark
# 88    7
# 55    5
# 78    3
# 79    3
# 75    2
# 60    2
# 85    2
# 69    2
# 89    1
# 54    1
# 94    1
# 65    1
# 18    1
# 81    1
# 86    1
# 90    1
# 96    1
# Name: count, dtype: int64

# %%
#access the third row and the second column in a DataFrame using .iloc
df.iloc[1,2]
# Out:
# 'Three'

# %%
df.loc[2,1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1097/678853884.py in <cell line: 0>()
# ----> 1 df.loc[2,1]
#
# ...

# %%
df.iloc[2,1]
# Out:
# 'Arnold'

# %%
df.loc[1,2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1097/1065354739.py in <cell line: 0>()
# ----> 1 df.loc[1,2]
#
# ...
